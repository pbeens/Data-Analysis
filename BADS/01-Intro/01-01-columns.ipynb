# %% [markdown]
# # Note to Data Dunkers Participants!
#
# All Data Dunkers content has been moved to a new repository. Pages in this Data Analysis repository may be repurposed to use new examples, so you are encouraged to use the new content located [here](https://github.com/pbeens/Data-Dunkers).
#
# ---

# %% [markdown]
# This notebook has been adapted from...
#
# https://github.com/callysto/basketball-and-data-science/blob/main/content/01-introduction.ipynb, with permmission.
#
#
# (Open in [Callysto](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https://github.com/pbeens/Data-Analysis&branch=main&subPath=BADS/01-Intro/01-01-columns.ipynb&depth=1) | [Colab](https://githubtocolab.com/pbeens/Data-Analysis/blob/main/BADS/01-Intro/01-01-columns.ipynb))

# %% [markdown]
# # Let’s Get Our Data

# %%
import pandas as pd

# URL of the CSV file containing data for Pascal Siakam
url = 'https://raw.githubusercontent.com/callysto/basketball-and-data-science/main/content/data/nba-players/Pascal_Siakam.csv'

# Read the CSV file into a pandas DataFrame named df
df = pd.read_csv(url)

# Display the DataFrame
display(df)

# %% [markdown]
# You can inspect the raw CSV file [here](https://raw.githubusercontent.com/callysto/basketball-and-data-science/main/content/data/nba-players/Pascal_Siakam.csv).
#
# Notice that last row? Why might you have to keep that in mind?

# %% [markdown]
# # Looking at the Columns

# %% [markdown]
# There are lots of columns, so let's list them using the `columns` attribute.
#
# Notice there aren't any parentheses when we use `columns`.

# %%
display(df.columns)

# %% [markdown]
# A different way we can look at the columns could be to use a `for loop`:

# %%
for column in df.columns:
    print(column)

# %% [markdown]
# Here's what all the columns mean:
#
# |Column|Meaning|Column|Meaning|
# |:-:|-|:-:|-|
# | **2P** | 2-Point Field Goals Per Game | **2P%** | 2-Point Field Goal Percentage |
# | **2PA** | 2-Point Field Goal Attempts Per Game | **3P** | 3-Point Field Goals Per Game |
# | **3P%** | 3-Point Field Goal Percentage | **3PA** | 3-Point Field Goal Attempts Per Game |
# | **AST** | Assists Per Game | **BLK** | Blocks Per Game |
# | **DRB** | Defensive Rebounds Per Game | **eFG%** | Effective Field Goal Percentage* |
# | **FG** | Field Goals Per Game | **FG%** | Field Goal Percentage |
# | **FGA** | Field Goal Attempts Per Game | **FT** | Free Throws Per Game |
# | **FT%** | Free Throw Percentage | **FTA** | Free Throw Attempts Per Game |
# | **G** | Games | **GS** | Games Started |
# | **Lg** | League | **MP** | Minutes Played Per Game |
# | **ORB** | Offensive Rebounds Per Game | **PF** | Personal Fouls Per Game |
# | **PTS** | Points Per Game | **Pos** | Position |
# | **STL** | Steals Per Game | **TOV** | Turnovers Per Game |
# | **TRB** | Total Rebounds Per Game |
#
# <span style="font-size:10px">*This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal.</span>

# %% [markdown]
# Let's just look at just the FG (Field Goals) column.

# %%
display(df['FG'])

# %% [markdown]
# What if we also want FGA (Field Goal Attempts Per Game)? Notice that now we put the column names in a list (`[ ]`), which are enclosed by brackets.

# %%
display(df[['FG', 'FGA']])

# %% [markdown]
# # Exercise
#
# Modify the code below to display the columns for Field Goal Percentage, 2-Point Field Goal Percentage, 3-Point Field Goal Percentage, and Free Throw Percentage.

# %%
import pandas as pd

# URL of the CSV file containing data for Pascal Siakam
url = 'https://raw.githubusercontent.com/callysto/basketball-and-data-science/main/content/data/nba-players/Pascal_Siakam.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(url)

# Display the DataFrame
display(df)

# %% [markdown]
# ---
# Next Lesson: [Filtering Data](01-02-filtering-data.ipynb) ([GitHub link](https://github.com/pbeens/Data-Analysis/blob/f74aee1f8912a8a1e80ec13c277203f62bebadc2/BADS/01-Intro/01-02-filtering-data.ipynb))
