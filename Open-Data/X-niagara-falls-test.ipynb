# %% [markdown]
# # IN PROGRESS!

# %% [markdown]
# #TODO Pick columns to plot, eventually compare to Toronto or other jurisdiction

# %%
import pandas as pd
import plotly.express as px

# %%
data_file = 'https://raw.githubusercontent.com/pbeens/Data-Analysis/main/Open-Data/Niagara-Falls-ON/Niagara_Falls_2021_Census_All_Data_1539938332032718836.csv'

# %%
df = pd.read_csv(data_file)

df.head()
# Out:
#    OBJECTID       CTUID                DGUID  CTNAME  LANDAREA  PRUID  \
# 0         1  5390209.03  2021S05075390209.03  209.03    2.7057     35
# 1         2  5390209.04  2021S05075390209.04  209.04    2.2632     35
# 2         3  5390209.05  2021S05075390209.05  209.05    2.7889     35
# 3         4  5390209.06  2021S05075390209.06  209.06    1.7335     35
# 4         5  5390202.00  2021S05075390202.00  202.00   17.0698     35
#
#      GEO_NAME  \
# 0  5390209.03
# 1  5390209.04
# 2  5390209.05
# 3  5390209.06
# 4  5390202.00
#
#    Total - Language spoken most often at home for the total population excluding institutional residents - 100% data (Total)  \
# 0                                               4975
# 1                                               3450
# 2                                               6490
# 3                                               2910
# 4                                               3865
#
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID', 'CTUID', 'DGUID', 'CTNAME', 'LANDAREA', 'PRUID', 'GEO_NAME',
#        'Total - Language spoken most often at home for the total population excluding institutional residents - 100% data (Total)',
#        'Single responses (Total)', 'Official languages (Total)',
#        ...
#        'Hungarian (Female)', 'Other languages, n.i.e. (Female)',
#        'Multiple responses (Female)', 'English and French (Female)',
#        'English and non-official language(s) (Female)',
#        'French and non-official language(s) (Female)',
#        'English, French and non-official language(s) (Female)',
#        'Multiple non-official languages (Female)', 'Shape__Area',
#        'Shape__Length'],
#       dtype='object', length=1002)
