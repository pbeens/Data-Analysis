# %% [markdown]
# Your goal for this assignment is to use the survey data from this morning create a histogram that looks like this:
#
# ![tcdsb-roles-example.png](attachment:tcdsb-roles-example.png)

# %% [markdown]
# The data for the survey can be found here:
#
# https://docs.google.com/spreadsheets/d/1rUC0mxONDI5zc1icnRP2y7q9RInq73-f1C7drgWYqHU/edit#gid=1374126757
#
# Here are some of the skills you used which may help you with this assignment:
#
# - [Importing from a Google Sheet](../Demos/where-can-we-get-data-from-google-sheet.ipynb)
# - [Creating a Histogram](../BADS/03-statistics/03-01-histograms.ipynb)
# - [Renaming Columns](../Demos/where-can-we-get-data-from-csv.ipynb)
#
# You can use the following "stub" to complete the assignment:

# %%
# what libraries have to be imported?
import 
import 

# remember to change the end of URL! 
url = ''

# create the dataframe
df = 

# rename the columns
df.columns = 

# plot the histogram
